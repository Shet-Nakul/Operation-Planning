# %%
attr_cfg = {
    "initialization": {
        "strategy": "random",
    },
    "search": {        
        "max_iterations": 100000,
        "max_minutes": 5,
        "tabu_tenure": 500,
        "switch_threshold": 2500,         
        "improvement_threshold": 0.001,   
        "restart_strategy": "adaptive_sigmoid",  
        "random_restart_interval": 5,
        "adaptive_schedule": "linear",
        "initial_temp": 50.0,
        "min_temp": 0.05,
        "annealing_duration": 500,
    },
    "moves": {
        "n_samples":3,              
        "n_samples_end": 2,
        "lns_samples": 3,
        "max_operations": 9,
        "max_operations_start":3,
        "max_block_size": 35,
    },
    "logging": {
        "log_interval": 500,
        "print_interval": 5000,
    },
}


from scheduling.search.cfg import SearchConfig

search_config = SearchConfig(**attr_cfg)

# %%
test_data = {
  "contracts": {
    "SAT-0001": None,
    "DYN-0001": [
      {
        "active": True,
        "hard": True,
        "name": "complete_weekends",
        "reason": "Employees should work either both weekend days or neither, avoiding split weekends",
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "no_free_day_before_working_weekend",
        "reason": "Avoid a free Friday immediately before a working weekend to maintain work continuity",
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "no_night_shift_before_free_weekend",
        "reason": "Avoid scheduling a night shift on Friday before a free weekend to ensure proper rest transition",
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "identical_shift_types_during_weekend",
        "reason": "Employees should work the same shift type on both Saturday and Sunday to maintain consistency",
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "max_num_assignments",
        "reason": "Limit total working days to prevent employee overload and ensure fair workload distribution",
        "value": 22,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "min_num_assignments",
        "reason": "Ensure a minimum number of working days to meet contractual obligations",
        "value": 18,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "max_consecutive_free_days",
        "reason": "Limit consecutive days off to avoid long absences that disrupt team coverage",
        "value": 5,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "min_consecutive_free_days",
        "reason": "Ensure rest periods are long enough for meaningful recovery between work stretches",
        "value": 2,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "max_consecutive_working_days",
        "reason": "Prevent long working stretches without rest to protect employee wellbeing",
        "value": 5,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "min_consecutive_working_days",
        "reason": "Avoid isolated single working days by requiring a minimum stretch length",
        "value": 3,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "max_consecutive_working_weekends",
        "reason": "Limit consecutive working weekends to ensure fair weekend distribution among staff",
        "value": 5,
        "weight": None
      },
      {
        "active": True,
        "hard": True,
        "name": "min_consecutive_working_weekends",
        "reason": "Avoid isolated single working weekends by grouping them for scheduling predictability",
        "value": 2,
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "late_followed_day",
        "pattern": [
          "L",
          "D"
        ],
        "reason": "Avoid a day shift immediately after a late shift due to insufficient rest time",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "day_followed_early_followed_day",
        "pattern": [
          "D",
          "E",
          "D"
        ],
        "reason": "Avoid sandwiching an early shift between two day shifts causing disruptive schedule changes",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "late_followed_early",
        "pattern": [
          "L",
          "E"
        ],
        "reason": "Prevent an early shift after a late shift as the turnaround time is too short for adequate rest",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "late_followed_night",
        "pattern": [
          "L",
          "N"
        ],
        "reason": "Prevent a night shift after a late shift due to insufficient recovery time between shifts",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "day_followed_night",
        "pattern": [
          "D",
          "N"
        ],
        "reason": "Avoid transitioning from a day shift directly to a night shift without a rest day",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "night_followed_day",
        "pattern": [
          "N",
          "D"
        ],
        "reason": "Prevent a day shift immediately after a night shift as the employee needs recovery time",
        "weight": None
      },
      {
        "active": True,
        "hard": False,
        "name": "night_followed_early",
        "pattern": [
          "N",
          "E"
        ],
        "reason": "Prevent an early shift after a night shift as the turnaround is critically short",
        "weight": None
      }
    ]
  },
  "employee_profiles": {
    "STAFF-0001": {
      "contract": "DYN-0001",
      "pools": [
        "TRA-SUR-0001"
      ],
      "roles_distribution": {
        "Charge Nurse": 0.25,
        "Preceptor": 0.1,
        "Senior Staff Nurse": 0.65
      }
    },
    "STAFF-0014": {
      "contract": "DYN-0001",
      "pools": [
        "TRA-SUR-0001"
      ],
      "roles_distribution": {
        "Nurse": 0.5,
        "Senior Staff Nurse": 0.5
      }
    },
    "STAFF-0016": {
      "contract": "SAT-0001",
      "pools": [
        "TRA-SUR-0001",
        "TRA-SUR-0002"
      ],
      "roles_distribution": {
        "Nurse": 0.5,
        "Senior Staff Nurse": 0.5
      },
      "weekly_template": {
        "monday": {"pool": "TRA-SUR-0001", "shift": "D"},
        "tuesday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "wednesday": {"pool": None, "shift": "D"},
        "thursday": {"pool": None, "shift": "D"},
        "friday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "saturday": {"pool": None, "shift": "O"},
        "sunday": {"pool": None, "shift": "O"}
      }
    },
    "STAFF-0017": {
      "contract": "SAT-0001",
      "pools": [
        "TRA-SUR-0001",
        "TRA-SUR-0002"
      ],
      "roles_distribution": {
        "Nurse": 0.5,
        "Senior Staff Nurse": 0.5
      },
      "weekly_template": {
        "monday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "tuesday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "wednesday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "thursday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "friday": {"pool": "TRA-SUR-0002", "shift": "D"},
        "saturday": {"pool": None, "shift": "O"},
        "sunday": {"pool": None, "shift": "O"}
      }
    }
  },
  "horizon": 31,
  "pool_role_map": {
    "TRA-SUR-0001": "Senior Surgeon",
    "TRA-SUR-0002": "Nurse"
  },
  "preferred_schedules": {
    "STAFF-0001": {
      "2026-07-01": { "pool": "TRA-SUR-0001", "shift": "D" , "status" : "ignored", "day_of_request" : "2026-06-01"},
      "2026-07-03": { "pool": "TRA-SUR-0001", "shift": "E" , "status" : "requested", "day_of_request" : "2026-06-09"},
      "2026-07-05": { "pool": None, "shift": "V" , "status" : "accepted", "day_of_request" : "2026-06-21"},
    },
    "STAFF-0016" : {
      "2026-07-01": { "pool": None, "shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"},
      "2026-07-02": { "pool": None, "shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"},
    },
    "STAFF-0017": {
      "2026-07-01": { "pool": None, "shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"},
      "2026-07-02": { "pool": None,"shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"},
      "2026-07-03": { "pool": None, "shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"},
      "2026-07-04": { "pool": None, "shift": "V", "status": "accepted", "day_of_request" : "2026-06-01"}}
  },
  "previous_schedules": {},
  "assigned_schedules": {},
  "shift_requirements": {
    "TRA-SUR-0001": {
      "D": {
        "friday": 1,
        "monday": 1,
        "saturday": 1,
        "sunday": 1,
        "thursday": 1,
        "tuesday": 1,
        "wednesday": 1
      },
      "E": {
        "friday": 1,
        "monday": 1,
        "saturday": 0,
        "sunday": 0,
        "thursday": 1,
        "tuesday": 1,
        "wednesday": 1
      },
      "L": {
        "friday": 1,
        "monday": 1,
        "saturday": 0,
        "sunday": 0,
        "thursday": 1,
        "tuesday": 1,
        "wednesday": 1
      },
      "N": {
        "friday": 1,
        "monday": 1,
        "saturday": 0,
        "sunday": 0,
        "thursday": 1,
        "tuesday": 1,
        "wednesday": 1
      }
    },
    "TRA-SUR-0002": {
      "D": {
        "friday": 1,
        "monday": 1,
        "saturday": 0,
        "sunday": 0,
        "thursday": 1,
        "tuesday": 1,
        "wednesday": 1
      },
    }
  },
  "start_date": "2026-07-01",
  "weighted_constraints": {"complete_weekends": 15,
              "no_free_day_before_working_weekend": 14,
              "no_night_shift_before_free_weekend": 14,
              "identical_shift_types_during_weekend": 8,
              "max_num_assignments": 12,
              "min_num_assignments": 10,
              "max_consecutive_free_days" : 5,
              "min_consecutive_free_days" : 10,
              "max_consecutive_working_days" : 25,
              "min_consecutive_working_days" : 5,
              "max_consecutive_working_weekends": 12,
              "min_consecutive_working_weekends": 3,
              "late_followed_day" : 14, 
              "day_followed_early_followed_day":12,
              "late_followed_early":28,
              "late_followed_night":28,
              "day_followed_night": 22,
              "night_followed_day": 35,
              "night_followed_early": 35,
              "assigned_schedules_non_working": 25,
              "assigned_schedules_working": 20,
              "preferred_schedules_non_working": 20,
              "preferred_schedules_working": 15,
              "preference_schedules_static_assignments": 10,
              "pool_shift_code" : 100
}
}

# %%
test_data
# Out:
# {'contracts': {'SAT-0001': None,
#   'DYN-0001': [{'active': True,
#     'hard': True,
#     'name': 'complete_weekends',
#     'reason': 'Employees should work either both weekend days or neither, avoiding split weekends',
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'no_free_day_before_working_weekend',
#     'reason': 'Avoid a free Friday immediately before a working weekend to maintain work continuity',
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'no_night_shift_before_free_weekend',
#     'reason': 'Avoid scheduling a night shift on Friday before a free weekend to ensure proper rest transition',
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'identical_shift_types_during_weekend',
#     'reason': 'Employees should work the same shift type on both Saturday and Sunday to maintain consistency',
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'max_num_assignments',
#     'reason': 'Limit total working days to prevent employee overload and ensure fair workload distribution',
#     'value': 22,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'min_num_assignments',
#     'reason': 'Ensure a minimum number of working days to meet contractual obligations',
#     'value': 18,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'max_consecutive_free_days',
#     'reason': 'Limit consecutive days off to avoid long absences that disrupt team coverage',
#     'value': 5,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'min_consecutive_free_days',
#     'reason': 'Ensure rest periods are long enough for meaningful recovery between work stretches',
#     'value': 2,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'max_consecutive_working_days',
#     'reason': 'Prevent long working stretches without rest to protect employee wellbeing',
#     'value': 5,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'min_consecutive_working_days',
#     'reason': 'Avoid isolated single working days by requiring a minimum stretch length',
#     'value': 3,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'max_consecutive_working_weekends',
#     'reason': 'Limit consecutive working weekends to ensure fair weekend distribution among staff',
#     'value': 5,
#     'weight': None},
#    {'active': True,
#     'hard': True,
#     'name': 'min_consecutive_working_weekends',
#     'reason': 'Avoid isolated single working weekends by grouping them for scheduling predictability',
#     'value': 2,
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'late_followed_day',
#     'pattern': ['L', 'D'],
#     'reason': 'Avoid a day shift immediately after a late shift due to insufficient rest time',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'day_followed_early_followed_day',
#     'pattern': ['D', 'E', 'D'],
#     'reason': 'Avoid sandwiching an early shift between two day shifts causing disruptive schedule changes',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'late_followed_early',
#     'pattern': ['L', 'E'],
#     'reason': 'Prevent an early shift after a late shift as the turnaround time is too short for adequate rest',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'late_followed_night',
#     'pattern': ['L', 'N'],
#     'reason': 'Prevent a night shift after a late shift due to insufficient recovery time between shifts',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'day_followed_night',
#     'pattern': ['D', 'N'],
#     'reason': 'Avoid transitioning from a day shift directly to a night shift without a rest day',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'night_followed_day',
#     'pattern': ['N', 'D'],
#     'reason': 'Prevent a day shift immediately after a night shift as the employee needs recovery time',
#     'weight': None},
#    {'active': True,
#     'hard': False,
#     'name': 'night_followed_early',
#     'pattern': ['N', 'E'],
#     'reason': 'Prevent an early shift after a night shift as the turnaround is critically short',
#     'weight': None}]},
#  'employee_profiles': {'STAFF-0001': {'contract': 'DYN-0001',
#    'pools': ['TRA-SUR-0001'],
#    'roles_distribution': {'Charge Nurse': 0.25,
#     'Preceptor': 0.1,
#     'Senior Staff Nurse': 0.65}},
#   'STAFF-0014': {'contract': 'DYN-0001',
#    'pools': ['TRA-SUR-0001'],
#    'roles_distribution': {'Nurse': 0.5, 'Senior Staff Nurse': 0.5}},
#   'STAFF-0016': {'contract': 'SAT-0001',
#    'pools': ['TRA-SUR-0001', 'TRA-SUR-0002'],
#    'roles_distribution': {'Nurse': 0.5, 'Senior Staff Nurse': 0.5},
#    'weekly_template': {'monday': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#     'tuesday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'wednesday': {'pool': None, 'shift': 'D'},
#     'thursday': {'pool': None, 'shift': 'D'},
#     'friday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'saturday': {'pool': None, 'shift': 'O'},
#     'sunday': {'pool': None, 'shift': 'O'}}},
#   'STAFF-0017': {'contract': 'SAT-0001',
#    'pools': ['TRA-SUR-0001', 'TRA-SUR-0002'],
#    'roles_distribution': {'Nurse': 0.5, 'Senior Staff Nurse': 0.5},
#    'weekly_template': {'monday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'tuesday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'wednesday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'thursday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'friday': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#     'saturday': {'pool': None, 'shift': 'O'},
#     'sunday': {'pool': None, 'shift': 'O'}}}},
#  'horizon': 31,
#  'pool_role_map': {'TRA-SUR-0001': 'Senior Surgeon', 'TRA-SUR-0002': 'Nurse'},
#  'preferred_schedules': {'STAFF-0001': {'2026-07-01': {'pool': 'TRA-SUR-0001',
#     'shift': 'D',
#     'status': 'ignored',
#     'day_of_request': '2026-06-01'},
#    '2026-07-03': {'pool': 'TRA-SUR-0001',
#     'shift': 'E',
#     'status': 'requested',
#     'day_of_request': '2026-06-09'},
#    '2026-07-05': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-21'}},
#   'STAFF-0016': {'2026-07-01': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'},
#    '2026-07-02': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'}},
#   'STAFF-0017': {'2026-07-01': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'},
#    '2026-07-02': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'},
#    '2026-07-03': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'},
#    '2026-07-04': {'pool': None,
#     'shift': 'V',
#     'status': 'accepted',
#     'day_of_request': '2026-06-01'}}},
#  'previous_schedules': {},
#  'assigned_schedules': {},
#  'shift_requirements': {'TRA-SUR-0001': {'D': {'friday': 1,
#     'monday': 1,
#     'saturday': 1,
#     'sunday': 1,
#     'thursday': 1,
#     'tuesday': 1,
#     'wednesday': 1},
#    'E': {'friday': 1,
#     'monday': 1,
#     'saturday': 0,
#     'sunday': 0,
#     'thursday': 1,
#     'tuesday': 1,
#     'wednesday': 1},
#    'L': {'friday': 1,
#     'monday': 1,
#     'saturday': 0,
#     'sunday': 0,
#     'thursday': 1,
#     'tuesday': 1,
#     'wednesday': 1},
#    'N': {'friday': 1,
#     'monday': 1,
#     'saturday': 0,
#     'sunday': 0,
#     'thursday': 1,
#     'tuesday': 1,
#     'wednesday': 1}},
#   'TRA-SUR-0002': {'D': {'friday': 1,
#     'monday': 1,
#     'saturday': 0,
#     'sunday': 0,
#     'thursday': 1,
#     'tuesday': 1,
#     'wednesday': 1}}},
#  'start_date': '2026-07-01',
#  'weighted_constraints': {'complete_weekends': 15,
#   'no_free_day_before_working_weekend': 14,
#   'no_night_shift_before_free_weekend': 14,
#   'identical_shift_types_during_weekend': 8,
#   'max_num_assignments': 12,
#   'min_num_assignments': 10,
#   'max_consecutive_free_days': 5,
#   'min_consecutive_free_days': 10,
#   'max_consecutive_working_days': 25,
#   'min_consecutive_working_days': 5,
#   'max_consecutive_working_weekends': 12,
#   'min_consecutive_working_weekends': 3,
#   'late_followed_day': 14,
#   'day_followed_early_followed_day': 12,
#   'late_followed_early': 28,
#   'late_followed_night': 28,
#   'day_followed_night': 22,
#   'night_followed_day': 35,
#   'night_followed_early': 35,
#   'assigned_schedules_non_working': 25,
#   'assigned_schedules_working': 20,
#   'preferred_schedules_non_working': 20,
#   'preferred_schedules_working': 15,
#   'preference_schedules_static_assignments': 10,
#   'pool_shift_code': 100}}

# %%
from scheduling.dataloader.processor.factory import DataFactory
from scheduling.dataloader.processor.handlers import InputDataHandler, OutputHandler
from scheduling.dataloader.processor.cleaner import PreProcessingPipeline
from scheduling.search.move_config import MoveConfig
from scheduling.search.move_engine import MoveEvaluator, MoveExecutor, MoveGenerator
from scheduling.search.optimizer import AttributeOptimizer
from scheduling.search.state_manager import StateManager


validated_data = PreProcessingPipeline(test_data).run()
input_data_handler = InputDataHandler(input_data_model=validated_data)
data_factory = DataFactory(input_data_handler)
state_manager = StateManager(data_factory)
move_config = MoveConfig()
move_generator = MoveGenerator(
    data_factory,
    max_operations=search_config.moves.max_operations,
    max_block_size=search_config.moves.max_block_size,
)
move_evaluator = MoveEvaluator(data_factory)
move_executor = MoveExecutor()

optimizer = AttributeOptimizer(
    state_manager=state_manager,
    data_factory=data_factory,
    move_config=move_config,
    move_generator=move_generator,
    move_evaluator=move_evaluator,
    move_executor=move_executor,
    cfg=search_config,
    progress_callback=None,
)

results = optimizer.run()
output_handler = OutputHandler(
    input_data_handler=input_data_handler,
    result_array=optimizer._hybrid.best_solution,
)
response = output_handler.response()
# Out:
# Processing input data...
# <scheduling.dataloader.processor.handlers.InputDataHandler object at 0x1115c7190>
# Initial penalty: 422190.06
# [   5000/100000]   5.0% | penalty=262927.11 best=262927.11 | assign=138927.00 cover=124000.00 | mode=tabu temp=0.05 | stuck=153 impr=183 switches=6 | n_samples=3 max_ops=3 | 6s (864 it/s)
# [  10000/100000]  10.0% | penalty=258922.29 best=258922.29 | assign=138922.29 cover=120000.00 | mode=tabu temp=0.05 | stuck=411 impr=203 switches=12 | n_samples=3 max_ops=4 | 6s (1563 it/s)
# [  15000/100000]  15.0% | penalty=266941.83 best=258922.29 | assign=138941.82 cover=128000.00 | mode=tabu temp=0.05 | stuck=805 impr=203 switches=18 | n_samples=3 max_ops=4 | 7s (2268 it/s)
# [  20000/100000]  20.0% | penalty=258918.44 best=258918.44 | assign=138918.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=960 impr=218 switches=24 | n_samples=3 max_ops=4 | 7s (2931 it/s)
# [  25000/100000]  25.0% | penalty=258961.44 best=258918.44 | assign=138961.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=865 impr=218 switches=30 | n_samples=3 max_ops=5 | 7s (3553 it/s)
# [  30000/100000]  30.0% | penalty=258933.05 best=258918.44 | assign=138933.05 cover=120000.00 | mode=tabu temp=0.05 | stuck=507 impr=218 switches=36 | n_samples=3 max_ops=5 | 7s (4131 it/s)
# [  35000/100000]  35.0% | penalty=258933.17 best=258918.44 | assign=138932.98 cover=120000.00 | mode=annealing temp=0.29 | stuck=1782 impr=219 switches=41 | n_samples=3 max_ops=5 | 7s (4674 it/s)
# [  45000/100000]  45.0% | penalty=258922.69 best=258918.44 | assign=138922.82 cover=120000.00 | mode=annealing temp=0.58 | stuck=1901 impr=219 switches=51 | n_samples=3 max_ops=6 | 8s (5663 it/s)
# [  50000/100000]  50.0% | penalty=258953.02 best=258916.92 | assign=138953.04 cover=120000.00 | mode=tabu temp=0.05 | stuck=561 impr=242 switches=56 | n_samples=2 max_ops=6 | 8s (6112 it/s)
# [  55000/100000]  55.0% | penalty=258924.44 best=258916.92 | assign=138924.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=1154 impr=242 switches=60 | n_samples=2 max_ops=6 | 8s (6572 it/s)
# [  60000/100000]  60.0% | penalty=258960.44 best=258916.92 | assign=138960.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=1596 impr=242 switches=64 | n_samples=2 max_ops=7 | 9s (7012 it/s)
# [  65000/100000]  65.0% | penalty=258920.82 best=258916.92 | assign=138920.82 cover=120000.00 | mode=tabu temp=0.05 | stuck=1882 impr=242 switches=68 | n_samples=2 max_ops=7 | 9s (7428 it/s)
# [  70000/100000]  70.0% | penalty=258933.05 best=258916.92 | assign=138933.05 cover=120000.00 | mode=annealing temp=45.39 | stuck=2007 impr=242 switches=73 | n_samples=2 max_ops=7 | 9s (7827 it/s)
# [  75000/100000]  75.0% | penalty=258918.44 best=258916.92 | assign=138918.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=1965 impr=242 switches=76 | n_samples=2 max_ops=8 | 9s (8209 it/s)
# [  80000/100000]  80.0% | penalty=258924.44 best=258916.92 | assign=138924.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=1751 impr=242 switches=80 | n_samples=2 max_ops=8 | 9s (8567 it/s)
# [  85000/100000]  85.0% | penalty=258918.44 best=258916.92 | assign=138918.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=1358 impr=242 switches=84 | n_samples=2 max_ops=8 | 10s (8909 it/s)
# [  90000/100000]  90.0% | penalty=258924.44 best=258916.92 | assign=138924.44 cover=120000.00 | mode=tabu temp=0.05 | stuck=781 impr=242 switches=88 | n_samples=2 max_ops=8 | 10s (9233 it/s)
# [  95000/100000]  95.0% | penalty=258927.85 best=258916.92 | assign=138927.56 cover=120000.00 | mode=tabu temp=0.05 | stuck=13 impr=242 switches=92 | n_samples=2 max_ops=9 | 10s (9534 it/s)

# %%
response["employee_centric"]
# Out:
# {'STAFF-0001': {'2026-07-01': {'pool': None, 'shift': 'O'},
#   '2026-07-02': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-03': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-04': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-05': {'pool': None, 'shift': 'V'},
#   '2026-07-06': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-07': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-08': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-09': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-10': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-11': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-12': {'pool': None, 'shift': 'O'},
#   '2026-07-13': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-14': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-15': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-16': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-17': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-18': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-19': {'pool': None, 'shift': 'O'},
#   '2026-07-20': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-21': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-22': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-23': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-24': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-25': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-26': {'pool': None, 'shift': 'O'},
#   '2026-07-27': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-28': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-29': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-30': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-31': {'pool': 'TRA-SUR-0001', 'shift': 'L'}},
#  'STAFF-0014': {'2026-07-01': {'pool': None, 'shift': 'O'},
#   '2026-07-02': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-03': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-04': {'pool': None, 'shift': 'O'},
#   '2026-07-05': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-06': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-07': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-08': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-09': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-10': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-11': {'pool': None, 'shift': 'O'},
#   '2026-07-12': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-13': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-14': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-15': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-16': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-17': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-18': {'pool': None, 'shift': 'O'},
#   '2026-07-19': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-20': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-21': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-22': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-23': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-24': {'pool': 'TRA-SUR-0001', 'shift': 'L'},
#   '2026-07-25': {'pool': None, 'shift': 'O'},
#   '2026-07-26': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-27': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-28': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-29': {'pool': 'TRA-SUR-0001', 'shift': 'E'},
#   '2026-07-30': {'pool': 'TRA-SUR-0001', 'shift': 'N'},
#   '2026-07-31': {'pool': 'TRA-SUR-0001', 'shift': 'N'}},
#  'STAFF-0016': {'2026-07-01': {'pool': None, 'shift': 'V'},
#   '2026-07-02': {'pool': None, 'shift': 'V'},
#   '2026-07-03': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-04': {'pool': None, 'shift': 'O'},
#   '2026-07-05': {'pool': None, 'shift': 'O'},
#   '2026-07-06': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-07': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-08': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-09': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-10': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-11': {'pool': None, 'shift': 'O'},
#   '2026-07-12': {'pool': None, 'shift': 'O'},
#   '2026-07-13': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-14': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-15': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-16': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-17': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-18': {'pool': None, 'shift': 'O'},
#   '2026-07-19': {'pool': None, 'shift': 'O'},
#   '2026-07-20': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-21': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-22': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-23': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-24': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-25': {'pool': None, 'shift': 'O'},
#   '2026-07-26': {'pool': None, 'shift': 'O'},
#   '2026-07-27': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-28': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-29': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-30': {'pool': 'TRA-SUR-0001', 'shift': 'D'},
#   '2026-07-31': {'pool': 'TRA-SUR-0001', 'shift': 'D'}},
#  'STAFF-0017': {'2026-07-01': {'pool': None, 'shift': 'V'},
#   '2026-07-02': {'pool': None, 'shift': 'V'},
#   '2026-07-03': {'pool': None, 'shift': 'V'},
#   '2026-07-04': {'pool': None, 'shift': 'V'},
#   '2026-07-05': {'pool': None, 'shift': 'O'},
#   '2026-07-06': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-07': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-08': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-09': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-10': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-11': {'pool': None, 'shift': 'O'},
#   '2026-07-12': {'pool': None, 'shift': 'O'},
#   '2026-07-13': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-14': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-15': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-16': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-17': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-18': {'pool': None, 'shift': 'O'},
#   '2026-07-19': {'pool': None, 'shift': 'O'},
#   '2026-07-20': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-21': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-22': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-23': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-24': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-25': {'pool': None, 'shift': 'O'},
#   '2026-07-26': {'pool': None, 'shift': 'O'},
#   '2026-07-27': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-28': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-29': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-30': {'pool': 'TRA-SUR-0002', 'shift': 'D'},
#   '2026-07-31': {'pool': 'TRA-SUR-0002', 'shift': 'D'}}}

# %%
data_factory.off_shift_id
# Out:
# 1

# %%
input_data_handler.original_preferred_schedules
# Out:
# {'STAFF-0001': {'2026-07-01': {'pool': 'TRA-SUR-0001',
#    'shift': 'D',
#    'weight': None},
#   '2026-07-03': {'pool': 'TRA-SUR-0001', 'shift': 'E', 'weight': None},
#   '2026-07-05': {'pool': None, 'shift': 'V', 'weight': None}},
#  'STAFF-0016': {'2026-07-01': {'pool': None, 'shift': 'V', 'weight': None},
#   '2026-07-02': {'pool': None, 'shift': 'V', 'weight': None}}}

# %%
validated_data.preferred_schedules
# Out:
# {'STAFF-0001': {'2026-07-01': PoolShift(pool='TRA-SUR-0001', shift='D', weight=None),
#   '2026-07-03': PoolShift(pool='TRA-SUR-0001', shift='E', weight=None),
#   '2026-07-05': PoolShift(pool=None, shift='V', weight=None)},
#  'STAFF-0016': {'2026-07-01': PoolShift(pool=None, shift='V', weight=None),
#   '2026-07-02': PoolShift(pool=None, shift='V', weight=None)}}
